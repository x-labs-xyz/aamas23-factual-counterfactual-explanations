# %%
# import necessary libraries
import pandas as pd
import numpy as np
import csv
from numpy import std, mean, sqrt

# %%
# read csv files into dataframes
workers = pd.read_csv('datasets/users.csv')
defendants = pd.read_csv('datasets/defendants.csv')
results = pd.read_csv('datasets/results.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-3a32c063c864> in <module>
#       1 # read csv files into dataframes
# ----> 2 workers = pd.read_csv('datasets/users.csv')
#       3 defendants = pd.read_csv('datasets/defendants.csv')
#       4 results = pd.read_csv('datasets/results.csv')
#
# ...

# %% [markdown]
# ## Intro Survey Summary

# %%
print('How familiar are you with machine learning?')
print("baseline:")
print(workers.loc[(workers['treatment'] == 0)]['ml_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 0)]['ml_fam'])/len(workers.loc[(workers['treatment'] == 0)]))

print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['ml_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['ml_fam'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['ml_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['ml_fam'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['ml_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['ml_fam'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['ml_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['ml_fam'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['ml_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['ml_fam'])/len(workers.loc[(workers['treatment'] == 5)]))

# %%
print('How familiar are you with the U.S. Criminal Justice System?')
print("baseline:")
print(workers.loc[(workers['treatment'] == 0)]['cj_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 0)]['cj_fam'])/len(workers.loc[(workers['treatment'] == 0)]))

print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['cj_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['cj_fam'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['cj_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['cj_fam'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['cj_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['cj_fam'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['cj_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['cj_fam'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['cj_fam'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['cj_fam'])/len(workers.loc[(workers['treatment'] == 5)]))

# %% [markdown]
# ## Exit Survey Summary

# %%
print('How confident were you in your decisions?')
print("baseline:")
print(workers.loc[(workers['treatment'] == 0)]['confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 0)]['confidence'])/len(workers.loc[(workers['treatment'] == 0)]))

print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['confidence'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['confidence'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['confidence'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['confidence'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['confidence'])/len(workers.loc[(workers['treatment'] == 5)]))

# %%
print('How well do you think you did compared to other experiment participants?')
print("baseline:")
print(workers.loc[(workers['treatment'] == 0)]['relative_confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 0)]['relative_confidence'])/len(workers.loc[(workers['treatment'] == 0)]))

print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['relative_confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['relative_confidence'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['relative_confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['relative_confidence'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['relative_confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['relative_confidence'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['relative_confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['relative_confidence'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['relative_confidence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['relative_confidence'])/len(workers.loc[(workers['treatment'] == 5)]))

# %%
print('How much did the algorithms risk score influence your decision?')
print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['self_reported_influence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['self_reported_influence'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['self_reported_influence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['self_reported_influence'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['self_reported_influence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['self_reported_influence'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['self_reported_influence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['self_reported_influence'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['self_reported_influence'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['self_reported_influence'])/len(workers.loc[(workers['treatment'] == 5)]))

# %%
print('For each defendant, you were presented with an explanation shedding light on why the algorithm predicted a specific score for the defendant. How useful was that explanation?')
print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['self_reported_exp_usefulness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['self_reported_exp_usefulness'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['self_reported_exp_usefulness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['self_reported_exp_usefulness'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['self_reported_exp_usefulness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['self_reported_exp_usefulness'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['self_reported_exp_usefulness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['self_reported_exp_usefulness'])/len(workers.loc[(workers['treatment'] == 5)]))

# %%
print('How accurate do you think the risk score algorithm is?')
print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['self_reported_ra_accuracy'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['self_reported_ra_accuracy'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['self_reported_ra_accuracy'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['self_reported_ra_accuracy'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['self_reported_ra_accuracy'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['self_reported_ra_accuracy'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['self_reported_ra_accuracy'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['self_reported_ra_accuracy'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['self_reported_ra_accuracy'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['self_reported_ra_accuracy'])/len(workers.loc[(workers['treatment'] == 5)]))

# %%
print('How fair (i.e. neutral and unbiased) do you think the risk score algorithm is?')
print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['self_reported_ra_fairness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['self_reported_ra_fairness'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['self_reported_ra_fairness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['self_reported_ra_fairness'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['self_reported_ra_fairness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['self_reported_ra_fairness'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['self_reported_ra_fairness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['self_reported_ra_fairness'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['self_reported_ra_fairness'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['self_reported_ra_fairness'])/len(workers.loc[(workers['treatment'] == 5)]))

# %%
print('If one of the decisions you made goes wrong or is questioned, how well can you explain how you arrived at that decision?') 
print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['self_reported_exp_ability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['self_reported_exp_ability'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['self_reported_exp_ability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['self_reported_exp_ability'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['self_reported_exp_ability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['self_reported_exp_ability'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['self_reported_exp_ability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['self_reported_exp_ability'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['self_reported_exp_ability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['self_reported_exp_ability'])/len(workers.loc[(workers['treatment'] == 5)]))

# %%
print('If one of the decisions you made goes wrong or is questioned, how much accountability do you think you should face?') 
print("risk assessment model only (unexplained):")
print(workers.loc[(workers['treatment'] == 1)]['accountability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 1)]['accountability'])/len(workers.loc[(workers['treatment'] == 1)]))

print("diverse counterfactuals:")
print(workers.loc[(workers['treatment'] == 2)]['accountability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 2)]['accountability'])/len(workers.loc[(workers['treatment'] == 2)]))

print("selective counterfactuals:")
print(workers.loc[(workers['treatment'] == 3)]['accountability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 3)]['accountability'])/len(workers.loc[(workers['treatment'] == 3)]))

print("complete feature attribution:")
print(workers.loc[(workers['treatment'] == 4)]['accountability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 4)]['accountability'])/len(workers.loc[(workers['treatment'] == 4)]))

print("selective feature attribution:")
print(workers.loc[(workers['treatment'] == 5)]['accountability'].value_counts())
print('average: ', sum(workers.loc[(workers['treatment'] == 5)]['accountability'])/len(workers.loc[(workers['treatment'] == 5)]))
